# %% [markdown]
# ### Prepare structure for SIESTA calculation

# %% [markdown]
# Import libraries

# %%
from sisl import *

# %%
molecule=Geometry.read("structure.xyz")

# %%
print(molecule)
# Out:
# Geometry{na: 4, no: 4,
#  Atoms{species: 2,
#   Atom{O, Z: 8, mass(au): 15.99940, maxR: -1.00000,
#    Orbital{R: -1.00000, q0: 0.0}
#   }: 2,
#   Atom{H, Z: 1, mass(au): 1.00794, maxR: -1.00000,
#    Orbital{R: -1.00000, q0: 0.0}
#   }: 2,
#  },
#  maxR: -1.00000,
#  Lattice{nsc: [1 1 1],
#   origin=[0.0000, 0.0000, 0.0000],
#   A=[20.0000, 0.0000, 0.0000],
#   B=[0.0000, 20.0000, 0.0000],
#   C=[0.0000, 0.0000, 20.0000],
#   bc=[Periodic,
#       Periodic,
#       Periodic]
#  }
# }

# %%
molecule.plot()
# Out:
# /Users/jfaraudo/opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages/sisl/viz/processors/xarray.py:208: FutureWarning: Deleting a single level of a MultiIndex is deprecated. Previously, this deleted all levels of a MultiIndex. Please also drop the following variables: {'sc_atom'} to avoid an error in the future.
#   new[var] = new[var] * scale

# %% [markdown]
# ## Create fdf file

# %%
molecule.write("structure.fdf")

# %% [markdown]
# test that the fdf is correct

# %%
structure=Geometry.read("structure.fdf")

# %%
structure.plot()
# Out:
# /Users/jfaraudo/opt/anaconda3/envs/nanociencia/lib/python3.13/site-packages/sisl/viz/processors/xarray.py:208: FutureWarning:
#
# Deleting a single level of a MultiIndex is deprecated. Previously, this deleted all levels of a MultiIndex. Please also drop the following variables: {'sc_atom'} to avoid an error in the future.
